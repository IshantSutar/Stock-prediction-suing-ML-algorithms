# %%
import pandas as pd

df = pd.read_csv('MSFT.csv')

df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1986-03-13    0.088542    0.101563    0.088542    0.097222    0.060396
# 1     1986-03-14    0.097222    0.102431    0.097222    0.100694    0.062553
# 2     1986-03-17    0.100694    0.103299    0.100694    0.102431    0.063632
# 3     1986-03-18    0.102431    0.103299    0.098958    0.099826    0.062014
# 4     1986-03-19    0.099826    0.100694    0.097222    0.098090    0.060936
# ...          ...         ...         ...         ...         ...         ...
# 9459  2023-09-25  316.589996  317.670013  315.000000  317.540009  317.540009
# 9460  2023-09-26  315.130005  315.880005  310.019989  312.140015  312.140015
# 9461  2023-09-27  312.299988  314.299988  309.690002  312.790009  312.790009
# 9462  2023-09-28  310.989990  315.480011  309.450012  313.640015  313.640015
# 9463  2023-09-29  317.750000  319.470001  314.980011  315.750000  315.750000
#
#           Volume
# 0     1031788800
# 1      308160000
# 2      133171200
# 3       67766400
# 4       47894400
# ...          ...
# 9459    17836000
# 9460    26297600
# 9461    19410100
# 9462    19683600
# 9463    24140300
#
# [9464 rows x 7 columns]

# %%
df = df[['Date', 'Close']]

df
# Out:
#             Date       Close
# 0     1986-03-13    0.097222
# 1     1986-03-14    0.100694
# 2     1986-03-17    0.102431
# 3     1986-03-18    0.099826
# 4     1986-03-19    0.098090
# ...          ...         ...
# 9459  2023-09-25  317.540009
# 9460  2023-09-26  312.140015
# 9461  2023-09-27  312.790009
# 9462  2023-09-28  313.640015
# 9463  2023-09-29  315.750000
#
# [9464 rows x 2 columns]

# %%
import datetime

def str_to_datetime(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

datetime_object = str_to_datetime('1986-03-13')
datetime_object
# Out:
# datetime.datetime(1986, 3, 13, 0, 0)

# %%
df['Date'] = df['Date'].apply(str_to_datetime)

df['Date']
# Out:
# <ipython-input-4-a035e129bcba>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = df['Date'].apply(str_to_datetime)
# 0      1986-03-13
# 1      1986-03-14
# 2      1986-03-17
# 3      1986-03-18
# 4      1986-03-19
#           ...
# 9459   2023-09-25
# 9460   2023-09-26
# 9461   2023-09-27
# 9462   2023-09-28
# 9463   2023-09-29
# Name: Date, Length: 9464, dtype: datetime64[ns]

# %%
df
# Out:
#            Date       Close
# 0    1986-03-13    0.097222
# 1    1986-03-14    0.100694
# 2    1986-03-17    0.102431
# 3    1986-03-18    0.099826
# 4    1986-03-19    0.098090
# ...         ...         ...
# 9459 2023-09-25  317.540009
# 9460 2023-09-26  312.140015
# 9461 2023-09-27  312.790009
# 9462 2023-09-28  313.640015
# 9463 2023-09-29  315.750000
#
# [9464 rows x 2 columns]

# %%
df.index = df.pop('Date')
df
# Out:
#                  Close
# Date
# 1986-03-13    0.097222
# 1986-03-14    0.100694
# 1986-03-17    0.102431
# 1986-03-18    0.099826
# 1986-03-19    0.098090
# ...                ...
# 2023-09-25  317.540009
# 2023-09-26  312.140015
# 2023-09-27  312.790009
# 2023-09-28  313.640015
# 2023-09-29  315.750000
#
# [9464 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(df.index, df['Close'])

# %%
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date

  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)

    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))

    if last_time:
      break

    target_date = next_date

    if target_date == last_date:
      last_time = True

  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates

  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]

  ret_df['Target'] = Y

  return ret_df

# Start day second time around: '2022-10-03'
windowed_df = df_to_windowed_df(df,
                                '2022-10-03',
                                '2023-09-29',
                                n=3)
windowed_df
# Out:
#     Target Date    Target-3    Target-2    Target-1      Target
# 0    2022-10-03  241.070007  237.500000  232.899994  240.740005
# 1    2022-10-04  237.500000  232.899994  240.740005  248.880005
# 2    2022-10-05  232.899994  240.740005  248.880005  249.199997
# 3    2022-10-06  240.740005  248.880005  249.199997  246.789993
# 4    2022-10-07  248.880005  249.199997  246.789993  234.240005
# ..          ...         ...         ...         ...         ...
# 245  2023-09-25  320.769989  319.529999  317.010010  317.540009
# 246  2023-09-26  319.529999  317.010010  317.540009  312.140015
# 247  2023-09-27  317.010010  317.540009  312.140015  312.790009
# 248  2023-09-28  317.540009  312.140015  312.790009  313.640015
# 249  2023-09-29  312.140015  312.790009  313.640015  315.750000
#
# [250 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1)) # 1 coz we are doing univarient forecasting

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((250,), (250, 3, 1), (250,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])
model.compile(loss='mse',
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 5s 169ms/step - loss: 76359.0312 - mean_absolute_error: 273.6136 - val_loss: 107514.3984 - val_mean_absolute_error: 327.7704
# Epoch 2/100
# 7/7 [==============================] - 0s 10ms/step - loss: 76060.1328 - mean_absolute_error: 273.0716 - val_loss: 107114.5000 - val_mean_absolute_error: 327.1599
# Epoch 3/100
# 7/7 [==============================] - 0s 13ms/step - loss: 75677.7500 - mean_absolute_error: 272.3661 - val_loss: 106552.7031 - val_mean_absolute_error: 326.3001
# Epoch 4/100
# 7/7 [==============================] - 0s 13ms/step - loss: 75148.1641 - mean_absolute_error: 271.3954 - val_loss: 105799.5000 - val_mean_absolute_error: 325.1440
# Epoch 5/100
# 7/7 [==============================] - 0s 10ms/step - loss: 74493.3516 - mean_absolute_error: 270.1877 - val_loss: 104952.1562 - val_mean_absolute_error: 323.8382
# Epoch 6/100
# 7/7 [==============================] - 0s 12ms/step - loss: 73693.7031 - mean_absolute_error: 268.6969 - val_loss: 103772.9297 - val_mean_absolute_error: 322.0121
# Epoch 7/100
# 7/7 [==============================] - 0s 13ms/step - loss: 72503.0312 - mean_absolute_error: 266.4511 - val_loss: 101978.4766 - val_mean_absolute_error: 319.2135
# Epoch 8/100
# 7/7 [==============================] - 0s 9ms/step - loss: 70779.9922 - mean_absolute_error: 263.2084 - val_loss: 99442.3203 - val_mean_absolute_error: 315.2163
# Epoch 9/100
# 7/7 [==============================] - 0s 9ms/step - loss: 68623.6641 - mean_absolute_error: 259.0825 - val_loss: 96714.2266 - val_mean_absolute_error: 310.8589
# Epoch 10/100
# 7/7 [==============================] - 0s 13ms/step - loss: 66276.9375 - mean_absolute_error: 254.4990 - val_loss: 93598.5625 - val_mean_absolute_error: 305.8064
# Epoch 11/100
# 7/7 [==============================] - 0s 15ms/step - loss: 63584.5000 - mean_absolute_error: 249.1773 - val_loss: 90010.6094 - val_mean_absolute_error: 299.8820
# Epoch 12/100
# 7/7 [==============================] - 0s 9ms/step - loss: 60128.1289 - mean_absolute_error: 242.1398 - val_loss: 85005.4922 - val_mean_absolute_error: 291.4179
# Epoch 13/100
# 7/7 [==============================] - 0s 13ms/step - loss: 56153.6797 - mean_absolute_error: 233.7709 - val_loss: 80147.0781 - val_mean_absolute_error: 282.9592
# Epoch 14/100
# 7/7 [==============================] - 0s 10ms/step - loss: 51887.0703 - mean_absolute_error: 224.4590 - val_loss: 74172.2578 - val_mean_absolute_error: 272.1970
# Epoch 15/100
# 7/7 [==============================] - 0s 12ms/step - loss: 47038.4336 - mean_absolute_error: 213.4554 - val_loss: 68101.4766 - val_mean_absolute_error: 260.8073
# Epoch 16/100
# 7/7 [==============================] - 0s 10ms/step - loss: 42094.1367 - mean_absolute_error: 201.4099 - val_loss: 61458.3086 - val_mean_absolute_error: 247.7440
# Epoch 17/100
# 7/7 [==============================] - 0s 13ms/step - loss: 36595.5352 - mean_absolute_error: 187.2483 - val_loss: 53882.6016 - val_mean_absolute_error: 231.9517
# Epoch 18/100
# 7/7 [==============================] - 0s 9ms/step - loss: 30938.3848 - mean_absolute_error: 171.4982 - val_loss: 46649.5781 - val_mean_absolute_error: 215.7967
# Epoch 19/100
# 7/7 [==============================] - 0s 9ms/step - loss: 25488.1602 - mean_absolute_error: 154.7784 - val_loss: 39472.8086 - val_mean_absolute_error: 198.4730
# Epoch 20/100
# 7/7 [==============================] - 0s 10ms/step - loss: 20178.6777 - mean_absolute_error: 136.5845 - val_loss: 32205.3770 - val_mean_absolute_error: 179.2328
# Epoch 21/100
# 7/7 [==============================] - 0s 10ms/step - loss: 15247.6504 - mean_absolute_error: 117.0491 - val_loss: 25143.8672 - val_mean_absolute_error: 158.3111
# Epoch 22/100
# 7/7 [==============================] - 0s 10ms/step - loss: 10809.0977 - mean_absolute_error: 96.2001 - val_loss: 19318.9609 - val_mean_absolute_error: 138.7012
# Epoch 23/100
# 7/7 [==============================] - 0s 10ms/step - loss: 7446.4316 - mean_absolute_error: 77.2517 - val_loss: 14549.5176 - val_mean_absolute_error: 120.2838
# Epoch 24/100
# 7/7 [==============================] - 0s 13ms/step - loss: 4868.6138 - mean_absolute_error: 58.0175 - val_loss: 10247.4805 - val_mean_absolute_error: 100.8251
# Epoch 25/100
# 7/7 [==============================] - 0s 13ms/step - loss: 3124.8323 - mean_absolute_error: 41.7130 - val_loss: 7282.8057 - val_mean_absolute_error: 84.8639
# Epoch 26/100
# 7/7 [==============================] - 0s 10ms/step - loss: 2162.9160 - mean_absolute_error: 34.0038 - val_loss: 5409.1113 - val_mean_absolute_error: 72.9944
# Epoch 27/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1729.0084 - mean_absolute_error: 32.6937 - val_loss: 4127.9199 - val_mean_absolute_error: 63.6160
# Epoch 28/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1537.3694 - mean_absolute_error: 32.9836 - val_loss: 3390.2937 - val_mean_absolute_error: 57.5271
# Epoch 29/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1488.8198 - mean_absolute_error: 33.4090 - val_loss: 3029.2878 - val_mean_absolute_error: 54.2988
# Epoch 30/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1494.4736 - mean_absolute_error: 33.9671 - val_loss: 2842.4172 - val_mean_absolute_error: 52.5499
# Epoch 31/100
# 7/7 [==============================] - 0s 13ms/step - loss: 1497.3877 - mean_absolute_error: 34.1446 - val_loss: 2778.2905 - val_mean_absolute_error: 51.9361
# Epoch 32/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1499.7778 - mean_absolute_error: 34.2199 - val_loss: 2796.0732 - val_mean_absolute_error: 52.1070
# Epoch 33/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1497.6001 - mean_absolute_error: 34.1505 - val_loss: 2848.4866 - val_mean_absolute_error: 52.6076
# Epoch 34/100
# 7/7 [==============================] - 0s 13ms/step - loss: 1494.4218 - mean_absolute_error: 34.0094 - val_loss: 2947.9209 - val_mean_absolute_error: 53.5443
# Epoch 35/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1492.0547 - mean_absolute_error: 33.8518 - val_loss: 3053.5583 - val_mean_absolute_error: 54.5218
# Epoch 36/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1493.1963 - mean_absolute_error: 33.7245 - val_loss: 3112.9868 - val_mean_absolute_error: 55.0641
# Epoch 37/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1493.6345 - mean_absolute_error: 33.6896 - val_loss: 3109.0940 - val_mean_absolute_error: 55.0288
# Epoch 38/100
# 7/7 [==============================] - 0s 13ms/step - loss: 1493.3018 - mean_absolute_error: 33.6909 - val_loss: 3109.7234 - val_mean_absolute_error: 55.0345
# Epoch 39/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1493.8019 - mean_absolute_error: 33.6642 - val_loss: 3154.2410 - val_mean_absolute_error: 55.4375
# Epoch 40/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1493.9027 - mean_absolute_error: 33.6073 - val_loss: 3175.5466 - val_mean_absolute_error: 55.6293
# Epoch 41/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1494.4578 - mean_absolute_error: 33.5945 - val_loss: 3174.0979 - val_mean_absolute_error: 55.6163
# Epoch 42/100
# 7/7 [==============================] - 0s 14ms/step - loss: 1494.6763 - mean_absolute_error: 33.5925 - val_loss: 3177.9651 - val_mean_absolute_error: 55.6511
# Epoch 43/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1494.7483 - mean_absolute_error: 33.6288 - val_loss: 3127.1987 - val_mean_absolute_error: 55.1936
# Epoch 44/100
# 7/7 [==============================] - 0s 13ms/step - loss: 1489.7677 - mean_absolute_error: 33.5576 - val_loss: 3169.4653 - val_mean_absolute_error: 55.5772
# Epoch 45/100
# 7/7 [==============================] - 0s 11ms/step - loss: 1493.4459 - mean_absolute_error: 33.4812 - val_loss: 3176.9624 - val_mean_absolute_error: 55.6452
# Epoch 46/100
# 7/7 [==============================] - 0s 11ms/step - loss: 1469.0411 - mean_absolute_error: 33.1595 - val_loss: 3426.8296 - val_mean_absolute_error: 57.8676
# Epoch 47/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1436.9667 - mean_absolute_error: 32.3485 - val_loss: 3257.6377 - val_mean_absolute_error: 56.3984
# Epoch 48/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1379.7043 - mean_absolute_error: 31.6341 - val_loss: 2897.1240 - val_mean_absolute_error: 53.0884
# Epoch 49/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1322.3773 - mean_absolute_error: 30.9924 - val_loss: 3222.6296 - val_mean_absolute_error: 56.1528
# Epoch 50/100
# 7/7 [==============================] - 0s 11ms/step - loss: 1208.4490 - mean_absolute_error: 29.0167 - val_loss: 4164.1436 - val_mean_absolute_error: 64.0567
# Epoch 51/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1270.0106 - mean_absolute_error: 29.5693 - val_loss: 2664.6157 - val_mean_absolute_error: 50.9485
# Epoch 52/100
# 7/7 [==============================] - 0s 13ms/step - loss: 1144.6442 - mean_absolute_error: 28.1914 - val_loss: 2673.2532 - val_mean_absolute_error: 51.0711
# Epoch 53/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1123.4033 - mean_absolute_error: 28.3583 - val_loss: 2552.1477 - val_mean_absolute_error: 49.8842
# Epoch 54/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1024.4370 - mean_absolute_error: 26.9214 - val_loss: 2299.3044 - val_mean_absolute_error: 47.3034
# Epoch 55/100
# 7/7 [==============================] - 0s 10ms/step - loss: 900.2908 - mean_absolute_error: 25.1108 - val_loss: 2144.5486 - val_mean_absolute_error: 45.6659
# Epoch 56/100
# 7/7 [==============================] - 0s 13ms/step - loss: 828.2109 - mean_absolute_error: 23.9908 - val_loss: 1831.9617 - val_mean_absolute_error: 42.0992
# Epoch 57/100
# 7/7 [==============================] - 0s 10ms/step - loss: 711.5449 - mean_absolute_error: 21.6476 - val_loss: 1588.8542 - val_mean_absolute_error: 39.1460
# Epoch 58/100
# 7/7 [==============================] - 0s 12ms/step - loss: 602.8597 - mean_absolute_error: 19.4999 - val_loss: 1281.4985 - val_mean_absolute_error: 34.9941
# Epoch 59/100
# 7/7 [==============================] - 0s 9ms/step - loss: 498.2524 - mean_absolute_error: 17.5348 - val_loss: 1129.8082 - val_mean_absolute_error: 32.7494
# Epoch 60/100
# 7/7 [==============================] - 0s 10ms/step - loss: 433.5960 - mean_absolute_error: 15.9675 - val_loss: 833.5125 - val_mean_absolute_error: 27.8555
# Epoch 61/100
# 7/7 [==============================] - 0s 13ms/step - loss: 347.6568 - mean_absolute_error: 14.0458 - val_loss: 715.5745 - val_mean_absolute_error: 25.7268
# Epoch 62/100
# 7/7 [==============================] - 0s 15ms/step - loss: 263.6159 - mean_absolute_error: 11.8339 - val_loss: 790.2282 - val_mean_absolute_error: 27.3392
# Epoch 63/100
# 7/7 [==============================] - 0s 12ms/step - loss: 246.5654 - mean_absolute_error: 11.9829 - val_loss: 417.2112 - val_mean_absolute_error: 19.1052
# Epoch 64/100
# 7/7 [==============================] - 0s 10ms/step - loss: 196.2853 - mean_absolute_error: 10.5672 - val_loss: 299.7334 - val_mean_absolute_error: 15.7170
# Epoch 65/100
# 7/7 [==============================] - 0s 13ms/step - loss: 156.4127 - mean_absolute_error: 9.1813 - val_loss: 311.3369 - val_mean_absolute_error: 16.3630
# Epoch 66/100
# 7/7 [==============================] - 0s 13ms/step - loss: 134.8058 - mean_absolute_error: 8.6435 - val_loss: 194.0218 - val_mean_absolute_error: 12.1006
# Epoch 67/100
# 7/7 [==============================] - 0s 9ms/step - loss: 111.4960 - mean_absolute_error: 7.8913 - val_loss: 136.1507 - val_mean_absolute_error: 9.3945
# Epoch 68/100
# 7/7 [==============================] - 0s 13ms/step - loss: 102.3971 - mean_absolute_error: 7.7768 - val_loss: 168.2196 - val_mean_absolute_error: 11.4299
# Epoch 69/100
# 7/7 [==============================] - 0s 12ms/step - loss: 90.6518 - mean_absolute_error: 7.3596 - val_loss: 168.7437 - val_mean_absolute_error: 11.6849
# Epoch 70/100
# 7/7 [==============================] - 0s 12ms/step - loss: 80.4555 - mean_absolute_error: 6.8586 - val_loss: 108.5841 - val_mean_absolute_error: 8.6157
# Epoch 71/100
# 7/7 [==============================] - 0s 12ms/step - loss: 74.1478 - mean_absolute_error: 6.7053 - val_loss: 59.3280 - val_mean_absolute_error: 5.4373
# Epoch 72/100
# 7/7 [==============================] - 0s 10ms/step - loss: 83.5146 - mean_absolute_error: 7.4053 - val_loss: 58.7467 - val_mean_absolute_error: 5.5139
# Epoch 73/100
# 7/7 [==============================] - 0s 12ms/step - loss: 68.8895 - mean_absolute_error: 6.6527 - val_loss: 76.3470 - val_mean_absolute_error: 6.9297
# Epoch 74/100
# 7/7 [==============================] - 0s 18ms/step - loss: 71.0454 - mean_absolute_error: 6.8101 - val_loss: 68.0681 - val_mean_absolute_error: 6.4369
# Epoch 75/100
# 7/7 [==============================] - 0s 10ms/step - loss: 65.4219 - mean_absolute_error: 6.3757 - val_loss: 34.9501 - val_mean_absolute_error: 4.4023
# Epoch 76/100
# 7/7 [==============================] - 0s 9ms/step - loss: 57.8036 - mean_absolute_error: 6.0082 - val_loss: 32.7356 - val_mean_absolute_error: 4.3663
# Epoch 77/100
# 7/7 [==============================] - 0s 10ms/step - loss: 47.0205 - mean_absolute_error: 5.3948 - val_loss: 31.7193 - val_mean_absolute_error: 4.2577
# Epoch 78/100
# 7/7 [==============================] - 0s 12ms/step - loss: 53.3997 - mean_absolute_error: 5.8115 - val_loss: 44.9944 - val_mean_absolute_error: 4.8873
# Epoch 79/100
# 7/7 [==============================] - 0s 13ms/step - loss: 71.6693 - mean_absolute_error: 6.7722 - val_loss: 80.0408 - val_mean_absolute_error: 7.6484
# Epoch 80/100
# 7/7 [==============================] - 0s 13ms/step - loss: 68.3307 - mean_absolute_error: 6.7483 - val_loss: 52.1766 - val_mean_absolute_error: 5.5398
# Epoch 81/100
# 7/7 [==============================] - 0s 13ms/step - loss: 46.5482 - mean_absolute_error: 5.4710 - val_loss: 36.7814 - val_mean_absolute_error: 4.4186
# Epoch 82/100
# 7/7 [==============================] - 0s 9ms/step - loss: 47.0408 - mean_absolute_error: 5.6161 - val_loss: 74.8058 - val_mean_absolute_error: 7.3495
# Epoch 83/100
# 7/7 [==============================] - 0s 14ms/step - loss: 62.4149 - mean_absolute_error: 6.3356 - val_loss: 61.1377 - val_mean_absolute_error: 6.3324
# Epoch 84/100
# 7/7 [==============================] - 0s 10ms/step - loss: 59.1798 - mean_absolute_error: 6.1870 - val_loss: 39.1496 - val_mean_absolute_error: 4.7206
# Epoch 85/100
# 7/7 [==============================] - 0s 10ms/step - loss: 49.6599 - mean_absolute_error: 5.7563 - val_loss: 53.3563 - val_mean_absolute_error: 5.7756
# Epoch 86/100
# 7/7 [==============================] - 0s 12ms/step - loss: 56.9505 - mean_absolute_error: 6.0580 - val_loss: 38.1305 - val_mean_absolute_error: 4.6971
# Epoch 87/100
# 7/7 [==============================] - 0s 14ms/step - loss: 44.7899 - mean_absolute_error: 5.2972 - val_loss: 24.3133 - val_mean_absolute_error: 3.8927
# Epoch 88/100
# 7/7 [==============================] - 0s 11ms/step - loss: 37.9560 - mean_absolute_error: 4.8596 - val_loss: 23.3393 - val_mean_absolute_error: 3.9334
# Epoch 89/100
# 7/7 [==============================] - 0s 11ms/step - loss: 39.6589 - mean_absolute_error: 4.9109 - val_loss: 22.9008 - val_mean_absolute_error: 3.9134
# Epoch 90/100
# 7/7 [==============================] - 0s 14ms/step - loss: 36.3395 - mean_absolute_error: 4.7067 - val_loss: 25.3582 - val_mean_absolute_error: 4.2135
# Epoch 91/100
# 7/7 [==============================] - 0s 10ms/step - loss: 38.0412 - mean_absolute_error: 4.7940 - val_loss: 22.2207 - val_mean_absolute_error: 3.8947
# Epoch 92/100
# 7/7 [==============================] - 0s 11ms/step - loss: 36.0166 - mean_absolute_error: 4.6495 - val_loss: 39.1049 - val_mean_absolute_error: 5.3999
# Epoch 93/100
# 7/7 [==============================] - 0s 10ms/step - loss: 42.5243 - mean_absolute_error: 5.1116 - val_loss: 30.6577 - val_mean_absolute_error: 4.6127
# Epoch 94/100
# 7/7 [==============================] - 0s 10ms/step - loss: 38.8729 - mean_absolute_error: 4.9422 - val_loss: 26.1831 - val_mean_absolute_error: 4.2959
# Epoch 95/100
# 7/7 [==============================] - 0s 13ms/step - loss: 37.8055 - mean_absolute_error: 4.7430 - val_loss: 21.6025 - val_mean_absolute_error: 3.8114
# Epoch 96/100
# 7/7 [==============================] - 0s 12ms/step - loss: 51.0102 - mean_absolute_error: 5.6966 - val_loss: 22.0682 - val_mean_absolute_error: 3.7894
# Epoch 97/100
# 7/7 [==============================] - 0s 10ms/step - loss: 45.2754 - mean_absolute_error: 5.4587 - val_loss: 21.2733 - val_mean_absolute_error: 3.8519
# Epoch 98/100
# 7/7 [==============================] - 0s 13ms/step - loss: 40.9651 - mean_absolute_error: 5.0240 - val_loss: 22.9755 - val_mean_absolute_error: 3.7761
# Epoch 99/100
# 7/7 [==============================] - 0s 13ms/step - loss: 36.3969 - mean_absolute_error: 4.5518 - val_loss: 24.2153 - val_mean_absolute_error: 4.1107
# Epoch 100/100
# 7/7 [==============================] - 0s 13ms/step - loss: 34.3966 - mean_absolute_error: 4.5605 - val_loss: 33.6287 - val_mean_absolute_error: 4.8748

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 7/7 [==============================] - 0s 3ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 1/1 [==============================] - 0s 23ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 [==============================] - 0s 24ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations'])

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction
# Out:
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations',
            'Recursive Predictions'])
